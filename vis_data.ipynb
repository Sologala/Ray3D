# %%
from lib.dataset.h36m_dataset import Human36mDataset
GT_3D = "data/h36m/data_3d_h36m.npz"
GT_2D = "data/h36m/data_2d_h36m_gt.npz"

# %%
dataset = Human36mDataset(GT_3D, False)

# %%
dataset.subjects()
# Out:
# dict_keys(['S1', 'S5', 'S6', 'S7', 'S8', 'S9', 'S11'])

# %%
dataset.fps()
# Out:
# 50

# %%
dataset.skeleton()
